# %%
import pandas as pd #Using Pandas for dataframe

# %%
coin_list=['BTC','USDC','ALGO','AAVE','FIL','ETC','GRT','LTC','BCH','LINK','ETH','UNI','DOT','XLM','DOGE','USDT','ADA','XRP','EOS']
# Coin list obtained.

# %%
myVars = vars()
#converting string into variable

# %%
pd.options.display.float_format = '{:.4f}'.format

# %%
Dataframe_to_be_push=pd.DataFrame()

# %%
import requests
#Importing request to fetch live data of Crypto currency

# %%
for i in coin_list:
    print(i)
    x='https://min-api.cryptocompare.com/data/v2/histoday?fsym=Replace&tsym=USD&limit=2000'
    link = x.replace("Replace", i )
    s=requests.get(link)
    data=s.json()
    df = pd.DataFrame(data['Data']['Data'])
    df['time'] = pd.to_datetime(df['time'], unit='s')
    df["Symbol"]=i
    df2=df['Symbol']
    df.drop(['Symbol'],axis=1,inplace=True)
    df.drop(['conversionSymbol'],axis=1,inplace=True)
    df.drop(['conversionType'],axis=1,inplace=True)
    df.rename(columns={'time':'Time','high':'High','low':'Low','open':'Open','volumefrom':'Starting Day Volume','volumeto':'Closing Day Volume','close':'Close'},inplace=True)
    df=pd.concat([df2,df],axis=1)
    myVars[i] = df.copy()
    Dataframe_to_be_push=pd.concat([Dataframe_to_be_push,df],axis=0)
# Out:
# BTC
# USDC
# ALGO
# AAVE
# FIL
# ETC
# GRT
# LTC
# BCH
# LINK
# ETH
# UNI
# DOT
# XLM
# DOGE
# USDT
# ADA
# XRP
# EOS

# %%
Dataframe_to_be_push
# Out:
#      Symbol       Time      High       Low      Open  Starting Day Volume  \
# 0       BTC 2017-07-19 2412.3800 2243.1300 2320.2300          154319.0100
# 1       BTC 2017-07-20 2932.8100 2282.1100 2282.5800          310335.4300
# 2       BTC 2017-07-21 2873.9600 2622.5400 2866.0200          193756.9300
# 3       BTC 2017-07-22 2876.7100 2658.5900 2675.0800          121917.9500
# 4       BTC 2017-07-23 2856.6700 2675.6500 2836.5300          108229.7600
# ...     ...        ...       ...       ...       ...                  ...
# 1996    EOS 2023-01-05    0.9104    0.8858    0.9074         2872468.6000
# 1997    EOS 2023-01-06    0.8983    0.8709    0.8919         4351324.2600
# 1998    EOS 2023-01-07    0.9006    0.8831    0.8951         2474586.2400
# 1999    EOS 2023-01-08    0.9126    0.8813    0.8892         2519373.7800
# 2000    EOS 2023-01-09    0.9481    0.9092    0.9101         4980238.4200
#
#       Closing Day Volume     Close
# 0         357639189.5800 2282.5800
# ...

# %%
Dataframe_to_be_push.dtypes
# Out:
# Symbol                         object
# Time                   datetime64[ns]
# High                          float64
# Low                           float64
# Open                          float64
# Starting Day Volume           float64
# Closing Day Volume            float64
# Close                         float64
# dtype: object

# %%
Dataframe_to_be_push.reset_index(inplace=True)

# %%
Dataframe_to_be_push.drop(['index'],axis=1,inplace=True)

# %%
Dataframe_to_be_push
# Out:
#       Symbol       Time      High       Low      Open  Starting Day Volume  \
# 0        BTC 2017-07-19 2412.3800 2243.1300 2320.2300          154319.0100
# 1        BTC 2017-07-20 2932.8100 2282.1100 2282.5800          310335.4300
# 2        BTC 2017-07-21 2873.9600 2622.5400 2866.0200          193756.9300
# 3        BTC 2017-07-22 2876.7100 2658.5900 2675.0800          121917.9500
# 4        BTC 2017-07-23 2856.6700 2675.6500 2836.5300          108229.7600
# ...      ...        ...       ...       ...       ...                  ...
# 38014    EOS 2023-01-05    0.9104    0.8858    0.9074         2872468.6000
# 38015    EOS 2023-01-06    0.8983    0.8709    0.8919         4351324.2600
# 38016    EOS 2023-01-07    0.9006    0.8831    0.8951         2474586.2400
# 38017    EOS 2023-01-08    0.9126    0.8813    0.8892         2519373.7800
# 38018    EOS 2023-01-09    0.9481    0.9092    0.9101         4980238.4200
#
#        Closing Day Volume     Close
# ...

# %%
pip install psycopg2-binary
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 1.2/1.2 MB 1.3 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import psycopg2
import pandas as pd
from sqlalchemy import create_engine

# %%
conn_string = 'postgresql://postgres:Darknight123!@localhost/datawarehouse'
  
db = create_engine(conn_string)
conn = db.connect()
  
Dataframe_to_be_push.to_sql('data', con=conn, if_exists='replace', index=False)
conn = psycopg2.connect(conn_string)
conn.autocommit = True
cursor = conn.cursor()
  
sql1 = '''select * from data;'''
cursor.execute(sql1)
for i in cursor.fetchall():
    print(i)
  
# conn.commit()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3279         try:
# -> 3280             return fn()
#    3281         except dialect.dbapi.Error as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     309         """
# --> 310         return _ConnectionFairy._checkout(self)
#     311
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     867         if not fairy:
# --> 868             fairy = _ConnectionRecord.checkout(pool)
#     869
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     475     def checkout(cls, pool):
# --> 476         rec = pool._do_get()
#     477         try:
#
# ...
